# %%
n = int(input())
check = 1
while n != 1:
    if n % 2 == 0:
        n //= 2
    else:
        check = 0
        break
if check == 0:
    print('sai')  
else:
    print('true')
# Out:
# sai

# %%
n = int(input())
so = 0
k = 0
for i in range(1,n):
    if (i/2)*(1+i)<n:
        so = (i/2)*(1+i)
    else:
        k = i-1
        break
    
print(k)
# Out:
# 3

# %%
n = int(input())
tong = 0
check = 1
for i in range(1,n):
    a = (i/2)*

# %%
n = int(input())
tong = 0
i = 1
while True:
    
    if (tong + 1/i)<= n:
        tong += 1/i
    else:
        print(i)
        break
    i += 1
# Out:
# 36865412

# %%
to = -99999999999
nho = 9999999999
while True:
    n = int(input())
    if n == -1:
        print(to,nho)
        break
    else:
        to = max(to,n)
        nho = min(nho,n)
# Out:
# 234 -88

# %%
n = input()
