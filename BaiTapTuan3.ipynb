# %% [markdown]
# W3A1

# %%
n = int(input())
while n!= 0:
    print(n%10,end = '')
    n = n//10
if n ==0:
    print()
# Out:
# 4321

# %% [markdown]
# W3A2

# %%
a,b = map(int,input().split())
a,b = b,a
print(a,b)
# Out:
# 2 1

# %% [markdown]
# W3A3

# %%
n = int(input())
if n >0 and (n&(n-1)) ==0:
    print(n,'là lũy thừa của 2')
else :
    print(n,'không là lũy thữa của 2')
# Out:
# 56 không là lũy thữa của 2

# %% [markdown]
# W3A4

# %%
a,b = map(int,input().split())
print(a//b)
# Out:
# 51

# %% [markdown]
# W3A5

# %%
a,b = map(int,input().split())
if a%b==0:
    print(a//b)
else:
    print(a//b+1)
# Out:
# 1

# %% [markdown]
# W3A6

# %%
x = int(input())
if x%2 == 0:
    print('Even')
else:
    print('Odd')
# Out:
# Odd

# %% [markdown]
# W3A7

# %%
a = int(input())
b = int(input())
if a <0 and b<0:
    print('Yes')
else:
    print('No')
# Out:
# No

# %% [markdown]
# W3A8

# %%
a = input()
b = input()
if len(a)>len(b):
    print('True')
else:
    print('False')
# Out:
# False

# %% [markdown]
# W3A9

# %%
a = int(input())
b = int(input())
c = int(input())
if (a+b)>c and (a+c)>b and (b+c)>a:
    print('Yes')
else:
    print('No')
# Out:
# No

# %% [markdown]
# W3A10

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
if a>b and a>c and a>d :
    print(a)
elif b>a and b>c and b>d:
    print(b)
elif c>a and c>b and c>d :
    print(c)
else:
    print(d)
# Out:
# 4

# %% [markdown]
# W3A11

# %%
a = int(input())
b = int(input())
c = int(input())
if (a+b)>c and (a+c)>b and (b+c)>a:
    if a==b==c:
        print('tam giác đều')
    elif a==b!=c or a==c!=b or b==c!=a:
        print('tam giac can')
    else:
        print('tam giac thường')
else:
    print('không phải tam  giac')
# Out:
# tam giac thường

# %% [markdown]
# W3A12

# %%
n = int(input())
if n%400==0 or (n%4==0 and n%100!=0):
    print('Yes')
else:
    print('No')
# Out:
# No

# %% [markdown]
# W3A13

# %%
n = int(input())
if n<=50:
    print(n*1500)
elif n<50 and n<= 100:
    print(50*1500+(n-50)*2000)
else:
    print(50*1500+50*2000+(n-100)*3000)
# Out:
# 175000

# %% [markdown]
# W3A14

# %%
a = float(input())
b = float(input())
if a==0 and b==0:
    print('vô số nghiệm')
elif a==0 and b!=0:
    print('vô nghiệm')
elif a!=0 and b==0:
    print(0)
else:
    print(f'{-b/a:.2f}')
# Out:
# -0.51

# %% [markdown]
# W3A15

# %%
a = float(input())
if a>=8:
    print('giỏi')
elif a>=6.5:
    print('khá')
elif a >= 5:
    print('trung bình')
else:
    print('yếu')
# Out:
# khá

# %% [markdown]
# W3A16

# %%
a = float(input())
b = int(a)
if a>=0:
    if a-b==0:
        print(a,a,a)
    elif a-b>=0.5:
        print(b+1,b,b+1)
    else:
        print(b+1,b,b)
else:
    if a-b==0:
        print(a,a,a)
    elif a-b<=-0.5:
        print(b,b-1,b-1)
    else:
        print(b,b-1,b)
# Out:
# 8 7 7

# %% [markdown]
# W3A17

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
if b/a ==c/b==d/c:
    print('Yes')
else:
    print('no')
# Out:
# Yes
