# %% [markdown]
# W2A1

# %%
print("Hello World!")

# %% [markdown]
# W2A2

# %%
a=input()
print("Hi",a)

# %% [markdown]
# W2A3

# %%
a,b=map(int,input().split())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
print(f"{float(a/b):.2f}")
# Out:
# 3
# -1
# 2
# 0
# 1
# 0.50

# %% [markdown]
# W2A4

# %%
a1,b1,c1,a2,b2,a3=map(int,input().split())
print(f"{float(((a1+b1+c1)+(a2+b2)*2+a3*3)/10):.1f}")
# Out:
# 4.2

# %% [markdown]
# W2A5

# %%
a,b=map(int,input().split())
print(a**b)

# %% [markdown]
# W2A6

# %%
a=input()
print(chr(ord(a)-32))
# Out:
# A

# %% [markdown]
# W2A7

# %%
print(((13**2)*3)+5)
print(13**2*3+5)

# %% [markdown]
# W2A8

# %%
C=float(input())
print(9/5*C+32)
# Out:
# 35.6

# %% [markdown]
# W2A9

# %%
a=float(input())
print(a*(1+0,3+0,1)+10)

# %% [markdown]
# W2A10

# %%
a,b,c= map(str,input().split())
print("Hi",c+",",b,"and",a+".")
# Out:
# Hi alice, helen and bob.

# %% [markdown]
# W2A11

# %%
a,b = map(int, input().split())
print(a*3600+b*60)

# %% [markdown]
# W2A12

# %%
n=int(input())
print(n*n*6)

# %% [markdown]
# W2A13

# %%
a,b= map(int,input().split())
print((a*b)%10)
# Out:
# 6

# %% [markdown]
# W2A14

# %%
a,b=map(int,input().split())
a=a+b
b=a-b
a=a-b
print(a,b)

# %% [markdown]
# W2A15

# %%
print("spring \nsummer\nautumn \nwinter")
# Out:
# spring
# summer
# autumn
# winter
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# W2A16

# %%
print("spring \nsummer\nautumn \nwinter")

# %% [markdown]
# W2A17

# %%
print("*\n***\n****\n")
# Out:
# *
# **
# ***

# %% [markdown]
# W2A18

# %%
print("### # #   ### ###\n #  #  #   #   #\n #  #   #  #   #\n #  #  #   #   #\n #  # #    #   #")
# Out:
# ### # #   ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  # #    #   #

# %% [markdown]
# W2A19

# %%
n="Monday \n\
Tuesday \n\
Wednesday \n\
Thursday \n\
Friday \n\
Saturday \n\
Sunday"
print(n)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# W2A20

# %%
n="January \n\
February\n\
March\n\
April\n\
May\n\
June\n\
July\n\
August\n\
September\n\
October\n\
November\n\
December"
print(n)
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# W2A21

# %%
for i in range (0,10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
