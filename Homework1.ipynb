# %% [markdown]
# bai1

# %%
n=int(input())
print(2*n)

# %% [markdown]
# bai2

# %%
a,b=map(float,input().split())
print(f"{(a*b)-(a/2)**2*3.14:.2f}")
# Out:
# 4.86

# %% [markdown]
# bai3

# %%
a=input()

if(ord(a)<=90):
    print(chr(ord(a)+32))
else:
    print(chr(ord(a)-32))
# Out:
# z

# %% [markdown]
# bai4

# %%
a=input()
if((65<=ord(a) and 90>=ord(a)) or (97<=ord(a) and 123>=ord(a))):
    print(a,"la ky tu alphabet")
else:
    print(a,"khong phai la ky tu alphabet")
# Out:
# z la ky tu alphabet
